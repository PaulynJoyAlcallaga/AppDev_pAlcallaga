# %% [markdown]
# CHAPTER 1

# %% [markdown]
# ####Exercise 1
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') #the Letter P should be small letter
# Out:
# Hello world!

# %%
print('Hello world!') #no open parentheses
# Out:
# Hello world!

# %%
print('Hello world!') #there should be a qoute before and after the word
# Out:
# Hello world!

# %%
print('Hello world!') #there is doucle qoute after the word "world!"
# Out:
# Hello world!

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x) #no error

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1 #the x is big letter
print(x)

# %% [markdown]
# ##  Values or Literals
